# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rd

# %%
df = pd.read_csv('heart.xlsdf.head()')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.isnull().sum()
df.dropna()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df1 =df.loc[1:150,['age', 'sex' ,'cp','trestbps', 'chol', 'fbs', 'restecg' ]]
df1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg
# 1     53    1   0       140   203    1        0
# 2     70    1   0       145   174    0        1
# 3     61    1   0       148   203    0        1
# 4     62    0   0       138   294    1        1
# 5     58    0   0       100   248    0        0
# ..   ...  ...  ..       ...   ...  ...      ...
# 146   51    0   2       120   295    0        0
# 147   41    1   0       110   172    0        0
# 148   52    1   3       152   298    1        1
# 149   39    1   2       140   321    0        0
# 150   58    1   0       114   318    0        2
#
# [150 rows x 7 columns]

# %%
df2 =df.loc[150:300,['thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']]
df2
# Out:
#      thalach  exang  oldpeak  slope  ca  thal  target
# 150      140      0      4.4      0   3     1       0
# 151      195      0      0.0      2   1     3       0
# 152      171      0      0.0      2   2     3       0
# 153      147      0      0.4      1   0     3       1
# 154      132      1      1.8      2   3     3       0
# ..       ...    ...      ...    ...  ..   ...     ...
# 296       71      0      1.0      1   0     2       0
# 297      111      1      0.8      2   0     3       0
# 298      174      0      0.0      2   0     2       1
# 299      172      0      0.2      2   0     2       1
# 300      172      0      0.0      2   0     2       1
#
# [151 rows x 7 columns]

# %%
df_main =pd.concat([df1,df2])

# %%
df_main
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 1    53.0  1.0  0.0     140.0  203.0  1.0      0.0      NaN    NaN      NaN
# 2    70.0  1.0  0.0     145.0  174.0  0.0      1.0      NaN    NaN      NaN
# 3    61.0  1.0  0.0     148.0  203.0  0.0      1.0      NaN    NaN      NaN
# 4    62.0  0.0  0.0     138.0  294.0  1.0      1.0      NaN    NaN      NaN
# 5    58.0  0.0  0.0     100.0  248.0  0.0      0.0      NaN    NaN      NaN
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 296   NaN  NaN  NaN       NaN    NaN  NaN      NaN     71.0    0.0      1.0
# 297   NaN  NaN  NaN       NaN    NaN  NaN      NaN    111.0    1.0      0.8
# 298   NaN  NaN  NaN       NaN    NaN  NaN      NaN    174.0    0.0      0.0
# 299   NaN  NaN  NaN       NaN    NaN  NaN      NaN    172.0    0.0      0.2
# 300   NaN  NaN  NaN       NaN    NaN  NaN      NaN    172.0    0.0      0.0
#
#      slope   ca  thal  target
# ...

# %%
import pandas as pd
heart_data = pd.read_csv('heart.xls')
column_to_transform ='restecg'
heart_data[column_to_transform] = heart_data[column_to_transform].replace({1:True,0:False})
heart_data.to_csv('transformed_heart.csv',index=True)

# %%
heart_data
# Out:
#       age  sex  cp  trestbps  chol  fbs restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0    True      168      0      1.0
# 1      53    1   0       140   203    1   False      155      1      3.1
# 2      70    1   0       145   174    0    True      125      1      2.6
# 3      61    1   0       148   203    0    True      161      0      0.0
# 4      62    0   0       138   294    1    True      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...     ...      ...    ...      ...
# 1020   59    1   1       140   221    0    True      164      1      0.0
# 1021   60    1   0       125   258    0   False      141      1      2.8
# 1022   47    1   0       110   275    0   False      118      1      1.0
# 1023   50    0   0       110   254    0   False      159      0      0.0
# 1024   54    1   0       120   188    0    True      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df['oldpeak']= df['oldpeak'].astype(int)

# %%
df.dtypes
# Out:
# age         int64
# sex         int64
# cp          int64
# trestbps    int64
# chol        int64
# fbs         int64
# restecg     int64
# thalach     int64
# exang       int64
# oldpeak     int64
# slope       int64
# ca          int64
# thal        int64
# target      int64
# dtype: object

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1        0
# 1021   60    1   0       125   258    0        0      141      1        2
# 1022   47    1   0       110   275    0        0      118      1        1
# 1023   50    0   0       110   254    0        0      159      0        0
# 1024   54    1   0       120   188    0        1      113      0        1
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.groupby('target').mean()
# Out:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.569138  0.827655  0.482966  134.106212  251.292585  0.164329
# 1       52.408745  0.570342  1.378327  129.245247  240.979087  0.134981
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.456914  139.130261  0.549098  1.274549  1.166333  1.158317  2.539078
# 1       0.598859  158.585551  0.134981  0.342205  1.593156  0.370722  2.119772

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0        1      2
# 1   53    1   0       140   203    1        0      155      1        3      0
# 2   70    1   0       145   174    0        1      125      1        2      0
# 3   61    1   0       148   203    0        1      161      0        0      2
# 4   62    0   0       138   294    1        1      106      0        1      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df['ca'].unique()
# Out:
# array([2, 0, 1, 3, 4])

# %%
df.ca.value_counts()
# Out:
# ca
# 0    578
# 1    226
# 2    134
# 3     69
# 4     18
# Name: count, dtype: int64

# %%
df.count()
# Out:
# age         1025
# sex         1025
# cp          1025
# trestbps    1025
# chol        1025
# fbs         1025
# restecg     1025
# thalach     1025
# exang       1025
# oldpeak     1025
# slope       1025
# ca          1025
# thal        1025
# target      1025
# dtype: int64

# %%
heart_data =pd.read_csv('heart.xls')

# %%
x_column ='age'
y_column ='chol'

# %%
plt.scatter(heart_data[x_column],heart_data[y_column],color ='skyblue')
plt.title(f'Scatter plot between {x_column} and {y_column}')
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
plt.show()
