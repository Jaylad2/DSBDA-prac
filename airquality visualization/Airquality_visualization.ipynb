# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rd
import seaborn as sns

# %%
ds =pd.read_csv("airquality.csv")

# %%
ds
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  153 non-null    int64
#  1   Ozone       116 non-null    float64
#  2   Solar.R     146 non-null    float64
#  3   Wind        153 non-null    float64
#  4   Temp        153 non-null    int64
#  5   Month       153 non-null    int64
#  6   Day         153 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 8.5 KB

# %%
import seaborn as sns
# %matplotlib inline #tells Jupyter to render the plots directly within
#the notebook's output cell.

# %%
plt.scatter(x='Ozone',y='Solar.R',data=ds,c='g')
plt.scatter(x='Ozone',y='Solar.R',data=ds,c='r',marker='+')
plt.xlabel('Ozone')
plt.ylabel('Ozone and Solar.R')
plt.legend(title='scatter_plot')
plt.show()

# %%
plt.figure()
sns.lmplot(x='Ozone',y='Solar.R',data=ds,fit_reg=False)
plt.show()

# %%
plt.figure()
ds.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.figure()
sns.displot(ds.Wind)

# %%
plt.figure()
plt.xlabel('Month')
plt.ylabel('count')
ds.Month.value_counts().plot(kind='bar')
# Out:
# <ipython-input-20-a0cf43016533>:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# <Axes: xlabel='Month', ylabel='count'>

# %%
plt.figure()
sns.countplot(ds.Month)
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure()
sns.lineplot(x='Temp',y='Month',data =ds)
# Out:
# <Axes: xlabel='Temp', ylabel='Month'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
ds['Month'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title('Distribution of Months')
plt.show()
